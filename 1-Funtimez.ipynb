# %%
# %run config.ipynb
import spotipy
import spotipy.util as util
import json
import import_ipynb
import config 
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import pprint



client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# importing Jupyter notebook from config.ipynb

# %%
#sp calls the api
def get_playlist_tracks(username, playlist_id, sp):
    offset=0
    #tracks = {}
    song_info = sp.user_playlist_tracks(username, playlist_id, limit=100, fields=None, offset=offset, market=None)
    #tracks.append(song_info)
    return song_info

def write_to_json(filename):
    with open(filename,'w') as fp:
        json.dump(filename, fp, indent=4)

# %%
song_info = get_playlist_tracks('lizzy_real', 'spotify:playlist:17GkBAfkdTCWA4bWbLSdh7', sp)
pprint.pprint(song_info['items'][14])
# Out:
# {'added_at': '2020-06-15T11:06:39Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/lizzy_real'},
#               'href': 'https://api.spotify.com/v1/users/lizzy_real',
#               'id': 'lizzy_real',
#               'type': 'user',
#               'uri': 'spotify:user:lizzy_real'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#                      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4IprNlQiJZUUJhDl0fL2SL'},
#                                   'href': 'https://api.spotify.com/v1/artists/4IprNlQiJZUUJhDl0fL2SL',
#                                   'id': '4IprNlQiJZUUJhDl0fL2SL',
#                                   'name': 'Quando Rondo',
#                                   'type': 'artist',
#                                   'uri': 'spotify:artist:4IprNlQiJZUUJhDl0fL2SL'}],
#                      'available_markets': ['AD',
# ...
